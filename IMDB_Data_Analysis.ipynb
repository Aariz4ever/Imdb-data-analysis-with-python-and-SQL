# %%
# Import Pandas and NumPy

import numpy as np
import pandas as pd

#pip install db-sqlite3
#SQLite in general is a server-less database that you can use within almost all programming languages including Python.
import sqlite3

# %% [markdown]
# We import the sqlite3 module and then create a connection object which will connect us to the database and will let us execute the SQL statements.
#
# sqlite3.connect(Database)
#
# __cursor()__ - we can use the cursor object to call the execute() method to execute any SQL queries.
#
# __STEPS:__
# To query data in an SQLite database from Python, you use these steps:
#
# - First, establish a connection to the SQLite database by creating a Connection object.
# - Next, create a Cursor object using the cursor method of the Connection object.
# - Then, execute a SELECT statement.
# - After that, call the fetchall() method of the cursor object to fetch the data.
# - Finally, loop the cursor and process each row individually.

# %%
db = 'movies.sqlite'


conn = sqlite3.connect(db)
cur = conn.cursor()

# %% [markdown]
# ## QUESTIONS
# ### Question 1: Can you get all data about movies?

# %%
cur.execute('SELECT * FROM movies')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

#movies -> if u print movies , all the data shown in list manner, can't understanadble

#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.

movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.



print('Shape of Movies data :',movies.shape)
print('\n\n\n')
movies.head(10)
#Displays first 3 rows in the table
# Out:
# Shape of Movies data : (4773, 13)
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
# 5  43602                              Spider-Man 3  258000000         115
# 6  43603                                   Tangled  260000000          48
# 7  43604                   Avengers: Age of Ultron  280000000         134
# 8  43605    Harry Potter and the Half-Blood Prince  250000000          98
# 9  43606        Batman v Superman: Dawn of Justice  250000000         155
#
#   release_date     revenue                                     title  \
# 0   2009-12-10  2787965087                                    Avatar
# 1   2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2   2015-10-26   880674609                                   Spectre
# 3   2012-07-16  1084939099                     The Dark Knight Rises
# 4   2012-03-07   284139100                               John Carter
# 5   2007-05-01   890871626                              Spider-Man 3
# 6   2010-11-24   591794936                                   Tangled
# 7   2015-04-22  1405403694                   Avengers: Age of Ultron
# 8   2009-07-07   933959197    Harry Potter and the Half-Blood Prince
# 9   2016-03-23   873260194        Batman v Superman: Dawn of Justice
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# 2           6.3        4466
# 3           7.6        9106
# 4           6.1        2124
# 5           5.9        3576
# 6           7.4        3330
# 7           7.3        6767
# 8           7.4        5293
# 9           5.7        7004
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
# 5  The seemingly invincible Spider-Man goes up ag...
# 6  When the kingdom's most wanted-and most charmi...
# 7  When Tony Stark tries to jumpstart a dormant p...
# 8  As Harry begins his sixth year at Hogwarts, he...
# 9  Fearing the actions of a god-like Super Hero l...
#
#                                           tagline     uid  director_id
# 0                     Enter the World of Pandora.   19995         4762
# 1  At the end of the world, the adventure begins.     285         4763
# 2                           A Plan No One Escapes  206647         4764
# 3                                 The Legend Ends   49026         4765
# 4            Lost in our world, found in another.   49529         4766
# 5                              The battle within.     559         4767
# 6        They're taking adventure to new lengths.   38757         4768
# 7                             A New Age Has Come.   99861         4769
# 8                           Dark Secrets Revealed     767         4770
# 9                              Justice or revenge  209112         4771

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4773 non-null   int64
#  1   original_title  4773 non-null   object
#  2   budget          4773 non-null   int64
#  3   popularity      4773 non-null   int64
#  4   release_date    4773 non-null   object
#  5   revenue         4773 non-null   int64
#  6   title           4773 non-null   object
#  7   vote_average    4773 non-null   float64
#  8   vote_count      4773 non-null   int64
#  9   overview        4770 non-null   object
#  10  tagline         3951 non-null   object
#  11  uid             4773 non-null   int64
#  12  director_id     4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# ## Question 2: How do you get all data about directors?

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(11)
# Out:
# Shape of Directors data : (2349, 5)
#                  name    id  gender    uid department
# 0       James Cameron  4762       2   2710  Directing
# 1      Gore Verbinski  4763       2   1704  Directing
# 2          Sam Mendes  4764       2     39  Directing
# 3   Christopher Nolan  4765       2    525  Directing
# 4      Andrew Stanton  4766       2      7  Directing
# 5           Sam Raimi  4767       2   7623  Directing
# 6        Byron Howard  4768       2  76595  Directing
# 7         Joss Whedon  4769       2  12891  Directing
# 8         David Yates  4770       2  11343  Directing
# 9         Zack Snyder  4771       2  15217  Directing
# 10       Bryan Singer  4772       2   9032  Directing

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# ## Question 3: Check how many movies are present in iMDB.

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(10)
# Out:
# Shape of Directors data : (2349, 5)
#                 name    id  gender    uid department
# 0      James Cameron  4762       2   2710  Directing
# 1     Gore Verbinski  4763       2   1704  Directing
# 2         Sam Mendes  4764       2     39  Directing
# 3  Christopher Nolan  4765       2    525  Directing
# 4     Andrew Stanton  4766       2      7  Directing
# 5          Sam Raimi  4767       2   7623  Directing
# 6       Byron Howard  4768       2  76595  Directing
# 7        Joss Whedon  4769       2  12891  Directing
# 8        David Yates  4770       2  11343  Directing
# 9        Zack Snyder  4771       2  15217  Directing

# %% [markdown]
# Note/ Analysis : I had generated virtual table with 3 columns of date, id and movies and I got results that POTC is the most awarded voted movie from Jan 1,2000

# %% [markdown]
# ## Question 4: Find these 3 directors: James Cameron ; Luc Besson ; John Woo

# %%
selecte = directors[directors["name"].isin(["Luc Besson", "James Cameron","John Woo"])]

# %%
selecte
# Out:
#               name    id  gender    uid department
# 0    James Cameron  4762       2   2710  Directing
# 131       John Woo  4893       2  11401  Directing
# 187     Luc Besson  4949       2     59  Directing

# %% [markdown]
# ## Question 5: Find all directors with name starting with Steven.

# %%
cur.execute("SELECT name FROM directors WHERE name LIKE 'Steven%'")
dr=cur.fetchall()
dr
# Out:
# [('Steven Spielberg',),
#  ('Steven Soderbergh',),
#  ('Steven Brill',),
#  ('Steven Zaillian',),
#  ('Steven Quale',),
#  ('Steven Seagal',),
#  ('Steven E. de Souza',),
#  ('Steven Shainberg',),
#  ('Steven R. Monroe',)]

# %%
filtered_df = directors[directors['name'].str.startswith('Steven')]
filtered_df['name']
# Out:
# 37        Steven Spielberg
# 147      Steven Soderbergh
# 251           Steven Brill
# 355        Steven Zaillian
# 454           Steven Quale
# 459          Steven Seagal
# 628     Steven E. de Souza
# 1041      Steven Shainberg
# 1951      Steven R. Monroe
# Name: name, dtype: object

# %% [markdown]
# ## Question 6: Count female directors

# %%
len(directors[directors["gender"]==1])
# Out:
# 150

# %% [markdown]
# ## Question 7: Find the name of the first 10 women directors

# %%
mov=movies
df = mov.rename(columns={'id': 'Id'})

# %%
df=df.rename(columns={'director_id':'id'})

# %%
join=pd.merge(df,directors,on='id')

# %%
join
# Out:
#          Id              original_title     budget  popularity release_date  \
# 0     43597                      Avatar  237000000         150   2009-12-10
# 1     43622                     Titanic  200000000         100   1997-11-18
# 2     43876  Terminator 2: Judgment Day  100000000         101   1991-07-01
# 3     43879                   True Lies  115000000          38   1994-07-14
# 4     44184                   The Abyss   70000000          24   1989-08-09
# ...     ...                         ...        ...         ...          ...
# 4768  48393                      Primer       7000          23   2004-10-08
# 4769  48394                      Cavite          0           0   2005-03-12
# 4770  48397   Signed, Sealed, Delivered          0           1   2013-10-13
# 4771  48398            Shanghai Calling          0           0   2012-05-03
# 4772  48399           My Date with Drew          0           1   2005-08-05
#
#          revenue                       title  vote_average  vote_count  \
# 0     2787965087                      Avatar           7.2       11800
# 1     1845034188                     Titanic           7.5        7562
# 2      520000000  Terminator 2: Judgment Day           7.7        4185
# 3      378882411                   True Lies           6.8        1116
# 4       90000098                   The Abyss           7.1         808
# ...          ...                         ...           ...         ...
# 4768      424760                      Primer           6.9         658
# 4769           0                      Cavite           7.5           2
# 4770           0   Signed, Sealed, Delivered           7.0           6
# 4771           0            Shanghai Calling           5.7           7
# 4772           0           My Date with Drew           6.3          16
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     84 years later, a 101-year-old woman named Ros...
# 2     Nearly 10 years have passed since Sarah Connor...
# 3     Harry Tasker is a secret agent for the United ...
# 4     A civilian oil rig crew is recruited to conduc...
# ...                                                 ...
# 4768  Friends/fledgling entrepreneurs invent a devic...
# 4769  Adam, a security guard, travels from Californi...
# 4770  "Signed, Sealed, Delivered" introduces a dedic...
# 4771  When ambitious New York attorney Sam is sent t...
# 4772  Ever since the second grade when he first saw ...
#
#                                                 tagline   uid_x    id  \
# 0                           Enter the World of Pandora.   19995  4762
# 1             Nothing on Earth could come between them.     597  4762
# 2                                It's nothing personal.     280  4762
# 3         When he said I do, he never said what he did.   36955  4762
# 4     There's everything you've ever known about adv...    2756  4762
# ...                                                 ...     ...   ...
# 4768                 What happens if it actually works?   14337  7106
# 4769                                               None   67238  7107
# 4770                                               None  231617  7108
# 4771                           A New Yorker in Shanghai  126186  7109
# 4772                                               None   25975  7110
#
#                   name  gender    uid_y department
# 0        James Cameron       2     2710  Directing
# 1        James Cameron       2     2710  Directing
# 2        James Cameron       2     2710  Directing
# 3        James Cameron       2     2710  Directing
# 4        James Cameron       2     2710  Directing
# ...                ...     ...      ...        ...
# 4768     Shane Carruth       2    76624  Directing
# 4769  Neill Dela Llana       0  1174437  Directing
# 4770       Scott Smith       0  1219158  Directing
# 4771       Daniel Hsia       2   208138  Directing
# 4772  Brian Herzlinger       2    85563  Directing
#
# [4773 rows x 17 columns]

# %%
womendir = join[join["gender"]==1]
womendir
# Out:
#          Id               original_title     budget  popularity release_date  \
# 251   43652                        Brave  185000000         125   2012-06-21
# 278   43658            Jupiter Ascending  176000003          85   2015-02-04
# 279   43720       The Matrix Revolutions  150000000          73   2003-11-05
# 280   43722          The Matrix Reloaded  150000000          70   2003-05-15
# 281   43822                  Speed Racer  120000000          17   2008-05-09
# ...     ...                          ...        ...         ...          ...
# 4687  48284                    Good Dick          0           1   2008-10-03
# 4688  48286    The Trials Of Darryl Hunt          0           0   2007-06-15
# 4709  48314         Your Sister's Sister     125000          12   2011-09-11
# 4726  48336  I Love You, Don't Touch Me!          0           0   1997-01-21
# 4735  48349               Tiny Furniture      65000           2   2010-11-12
#
#         revenue                        title  vote_average  vote_count  \
# 251   538983207                        Brave           6.7        4641
# 278   183987723            Jupiter Ascending           5.2        2768
# 279   424988211       The Matrix Revolutions           6.4        3096
# 280   738599701          The Matrix Reloaded           6.7        3443
# 281    93945766                  Speed Racer           5.7         354
# ...         ...                          ...           ...         ...
# 4687          0                    Good Dick           6.1          34
# 4688          0    The Trials Of Darryl Hunt           6.8           4
# 4709    3200000         Your Sister's Sister           6.5         137
# 4726          0  I Love You, Don't Touch Me!           6.0           1
# 4735     416498               Tiny Furniture           5.6          59
#
#                                                overview  \
# 251   Brave is set in the mystical Scottish Highland...
# 278   In a universe where human genetic material is ...
# 279   The human city of Zion defends itself against ...
# 280   Six months after the events depicted in The Ma...
# 281   Speed Racer is the tale of a young and brillia...
# ...                                                 ...
# 4687  A fidgety, wisecracking video store clerk deve...
# 4688  "The Trials of Darryl Hunt" is a feature docum...
# 4709  Iris invites her friend Jack to stay at her fa...
# 4726  The story of a 25 year old virgin girl, lookin...
# 4735  After graduating from film school, Aura return...
#
#                                                 tagline  uid_x    id  \
# 251                                   Change your fate.  62177  4801
# 278                               Expand your universe.  76757  4805
# 279         Everything that has a beginning has an end.    605  4805
# 280                                     Free your mind.    604  4805
# 281                                                 Go!   7459  4805
# ...                                                 ...    ...   ...
# 4687                     A hard man... is good to find.  14758  7027
# 4688                                               None  37985  7028
# 4709  A comedy about doing the right thing with the ...  84355  7049
# 4726  Just Your Typical Boy-Loves-Girl Who Doesn't L...  90414  7066
# 4735  Aura would like you to know that she is having...  47607  7075
#
#                  name  gender   uid_y department
# 251    Brenda Chapman       1   59803  Directing
# 278   Lilly Wachowski       1    9339  Directing
# 279   Lilly Wachowski       1    9339  Directing
# 280   Lilly Wachowski       1    9339  Directing
# 281   Lilly Wachowski       1    9339  Directing
# ...               ...     ...     ...        ...
# 4687   Marianna Palka       1   77775  Directing
# 4688      Ricki Stern       1   74105  Directing
# 4709     Lynn Shelton       1   90492  Directing
# 4726      Julie Davis       1   87033  Directing
# 4735      Lena Dunham       1  139135  Directing
#
# [243 rows x 17 columns]

# %%
new=womendir.sort_values(by="release_date")

# %%
new["name"].head(10)
# Out:
# 3792      Sharron Miller
# 3036        Nancy Walker
# 2990      Amy Heckerling
# 4573    Amy Holden Jones
# 2247          Elaine May
# 2012      Penny Marshall
# 3291        Mary Lambert
# 2806      Rachel Talalay
# 2010      Penny Marshall
# 3464        Jane Campion
# Name: name, dtype: object

# %% [markdown]
# ## Question 8: What are the 3 most popular movies?

# %%
cur.execute('SELECT * FROM movies ORDER BY popularity DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies['original_title'].head(3)
# Out:
# 0         Minions
# 1    Interstellar
# 2        Deadpool
# Name: original_title, dtype: object

# %% [markdown]
# ## Question 9: What are the 3 most bankable movies?

# %%
#bankable = revenue - budget
cur.execute('SELECT * FROM movies ORDER BY revenue - budget DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies['original_title'].head(3)
# Out:
# 0            Avatar
# 1           Titanic
# 2    Jurassic World
# Name: original_title, dtype: object

# %% [markdown]
# ## Question 10: What is the most awarded average vote since the january 1st, 2000?

# %%
cur.execute("SELECT MAX(vote_average) FROM movies WHERE release_date > '2000-01-01' ORDER BY release_date")
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['vote_average'])
movies
# Out:
#    vote_average
# 0           9.5

# %%
mov["release_date"]=pd.to_datetime(mov["release_date"])

# %%
mov["releaseYear"] = mov.release_date.dt.date

# %%
y=mov["release_date"].max()

# %%
y
# Out:
# Timestamp('2017-02-03 00:00:00')

# %%
per1 = mov[mov['release_date'].between('2000-01-01',y)]
t=per1["vote_average"].max()
t
# Out:
# 9.5

# %%
per1[per1["vote_average"]==per1["vote_average"].max()]
# Out:
#          id original_title  budget  popularity release_date  revenue  \
# 3988  47589      Sardaarji       0           0   2015-06-26        0
#
#           title  vote_average  vote_count  \
# 3988  Sardaarji           9.5           2
#
#                                                overview tagline     uid  \
# 3988  A ghost hunter uses bottles to capture trouble...    None  346081
#
#       director_id releaseYear
# 3988         6588  2015-06-26

# %% [markdown]
# ## Question 11: Which movie(s) were directed by Brenda Chapman?

# %%
cur.execute('SELECT * FROM movies')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
#      release_date     revenue                                     title  \
# 0      2009-12-10  2787965087                                    Avatar
# 1      2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2      2015-10-26   880674609                                   Spectre
# 3      2012-07-16  1084939099                     The Dark Knight Rises
# 4      2012-03-07   284139100                               John Carter
# ...           ...         ...                                       ...
# 4768   1992-09-04     2040920                               El Mariachi
# 4769   2011-12-26           0                                 Newlyweds
# 4770   2013-10-13           0                 Signed, Sealed, Delivered
# 4771   2012-05-03           0                          Shanghai Calling
# 4772   2005-08-05           0                         My Date with Drew
#
#       vote_average  vote_count  \
# 0              7.2       11800
# 1              6.9        4500
# 2              6.3        4466
# 3              7.6        9106
# 4              6.1        2124
# ...            ...         ...
# 4768           6.6         238
# 4769           5.9           5
# 4770           7.0           6
# 4771           5.7           7
# 4772           6.3          16
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4768  El Mariachi just wants to play his guitar and ...
# 4769  A newlywed couple's honeymoon is upended by th...
# 4770  "Signed, Sealed, Delivered" introduces a dedic...
# 4771  When ambitious New York attorney Sam is sent t...
# 4772  Ever since the second grade when he first saw ...
#
#                                                 tagline     uid  director_id
# 0                           Enter the World of Pandora.   19995         4762
# 1        At the end of the world, the adventure begins.     285         4763
# 2                                 A Plan No One Escapes  206647         4764
# 3                                       The Legend Ends   49026         4765
# 4                  Lost in our world, found in another.   49529         4766
# ...                                                 ...     ...          ...
# 4768  He didn't come looking for trouble, but troubl...    9367         5097
# 4769  A newlywed couple's honeymoon is upended by th...   72766         6485
# 4770                                               None  231617         7108
# 4771                           A New Yorker in Shanghai  126186         7109
# 4772                                               None   25975         7110
#
# [4773 rows x 13 columns]

# %%
cur.execute('SELECT * FROM directors')
directors = cur.fetchall()
directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
directors
# Out:
#                    name    id  gender      uid department
# 0         James Cameron  4762       2     2710  Directing
# 1        Gore Verbinski  4763       2     1704  Directing
# 2            Sam Mendes  4764       2       39  Directing
# 3     Christopher Nolan  4765       2      525  Directing
# 4        Andrew Stanton  4766       2        7  Directing
# ...                 ...   ...     ...      ...        ...
# 2344      Shane Carruth  7106       2    76624  Directing
# 2345   Neill Dela Llana  7107       0  1174437  Directing
# 2346        Scott Smith  7108       0  1219158  Directing
# 2347        Daniel Hsia  7109       2   208138  Directing
# 2348   Brian Herzlinger  7110       2    85563  Directing
#
# [2349 rows x 5 columns]

# %%
# SELECT 
# tb_1.*,
# tb_2.*
# FROM [database_1].[table_schema].[table_name_1] tb_1
# JOIN [database_2].[table_schema].[table_name_2] tb_2 ON tb_1.id = tb_2.id
cur.execute("SELECT * FROM movies tb1 JOIN directors tb2 ON tb1.director_id = tb2.id WHERE name = 'Brenda Chapman'")
merge = cur.fetchall()
merge = pd.DataFrame(merge, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id','name', 'id', 'gender', 'uid', 'department'])
merge['original_title']
# Out:
# 0    Brave
# Name: original_title, dtype: object

# %%
directors[directors["name"]=="Brenda Chapman"].id
# Out:
# 39    4801
# Name: id, dtype: int64

# %%
mov[mov["director_id"]==int(directors[directors["name"]=="Brenda Chapman"].id)]
# Out:
# C:\Users\aariz\AppData\Local\Temp\ipykernel_5672\495559156.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   mov[mov["director_id"]==int(directors[directors["name"]=="Brenda Chapman"].id)]
#        id original_title     budget  popularity release_date    revenue  \
# 55  43652          Brave  185000000         125   2012-06-21  538983207
#
#     title  vote_average  vote_count  \
# 55  Brave           6.7        4641
#
#                                              overview            tagline  \
# 55  Brave is set in the mystical Scottish Highland...  Change your fate.
#
#       uid  director_id releaseYear
# 55  62177         4801  2012-06-21

# %% [markdown]
# ## Question 12: Whose director made the most movies?

# %%
directors[directors["id"]==mov["director_id"].value_counts().index.tolist()[0]]
# Out:
#                 name    id  gender  uid department
# 37  Steven Spielberg  4799       2  488  Directing

# %%
cur.execute("SELECT name,COUNT(*) count FROM movies tb1 JOIN directors tb2 ON tb1.director_id = tb2.id GROUP BY name ORDER BY count DESC")
merge = cur.fetchall()
merge = pd.DataFrame(merge, columns = ['name','count'])
merge['name'].head(1)
# Out:
# 0    Steven Spielberg
# Name: name, dtype: object

# %% [markdown]
# ## Question 13: Whose director is the most bankable?

# %%
cur.execute("SELECT name, SUM(revenue - budget) Bankable FROM movies tb1 JOIN directors tb2 ON tb1.director_id = tb2.id GROUP BY name ORDER BY Bankable DESC")
merge = cur.fetchall()
merge = pd.DataFrame(merge, columns = ['name','Bankable'])
merge.head(3)
# Out:
#                name    Bankable
# 0  Steven Spielberg  7479893164
# 1     Peter Jackson  5205642820
# 2     James Cameron  5136669439

# %% [markdown]
# # Budget Analysis

# %% [markdown]
# ## List out Top 10 highest budget made movies

# %%
cur.execute('SELECT * FROM movies ORDER BY budget DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies['original_title'].head(10)
# Out:
# 0    Pirates of the Caribbean: On Stranger Tides
# 1       Pirates of the Caribbean: At World's End
# 2                        Avengers: Age of Ultron
# 3                               Superman Returns
# 4                                    John Carter
# 5                                        Tangled
# 6                                   Spider-Man 3
# 7                                The Lone Ranger
# 8                          The Dark Knight Rises
# 9         Harry Potter and the Half-Blood Prince
# Name: original_title, dtype: object

# %% [markdown]
# # Popularity Analysis

# %% [markdown]
# ## List out Top 10 highest popularity made movies

# %%
cur.execute('SELECT original_title, popularity FROM movies ORDER BY popularity DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['original_title','popularity',])
movies.head(10)
# Out:
#                                       original_title  popularity
# 0                                            Minions         875
# 1                                       Interstellar         724
# 2                                           Deadpool         514
# 3                            Guardians of the Galaxy         481
# 4                                 Mad Max: Fury Road         434
# 5                                     Jurassic World         418
# 6  Pirates of the Caribbean: The Curse of the Bla...         271
# 7                     Dawn of the Planet of the Apes         243
# 8              The Hunger Games: Mockingjay - Part 1         206
# 9                                         Big Hero 6         203

# %%
movies.sort_values(by="popularity",ascending=False,ignore_index=True).head(10)["original_title"]
# Out:
# 0                                              Minions
# 1                                         Interstellar
# 2                                             Deadpool
# 3                              Guardians of the Galaxy
# 4                                   Mad Max: Fury Road
# 5                                       Jurassic World
# 6    Pirates of the Caribbean: The Curse of the Bla...
# 7                       Dawn of the Planet of the Apes
# 8                The Hunger Games: Mockingjay - Part 1
# 9                                           Big Hero 6
# Name: original_title, dtype: object

# %% [markdown]
# # Revenue Analysis

# %% [markdown]
# ## What are the top 10 Revenue movies

# %%
cur.execute('SELECT * FROM movies ORDER BY revenue DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies[['original_title','revenue']].head(10)
# Out:
#                original_title     revenue
# 0                      Avatar  2787965087
# 1                     Titanic  1845034188
# 2                The Avengers  1519557910
# 3              Jurassic World  1513528810
# 4                   Furious 7  1506249360
# 5     Avengers: Age of Ultron  1405403694
# 6                      Frozen  1274219009
# 7                  Iron Man 3  1215439994
# 8                     Minions  1156730962
# 9  Captain America: Civil War  1153304495

# %%
movies.sort_values(by="revenue",ascending=False,ignore_index = True).original_title.head(10)
# Out:
# 0                        Avatar
# 1                       Titanic
# 2                  The Avengers
# 3                Jurassic World
# 4                     Furious 7
# 5       Avengers: Age of Ultron
# 6                        Frozen
# 7                    Iron Man 3
# 8                       Minions
# 9    Captain America: Civil War
# Name: original_title, dtype: object

# %% [markdown]
# # Voting Analysis

# %% [markdown]
# ## Display most popular movies with vote_average

# %%
cur.execute('SELECT * FROM movies ORDER BY popularity DESC')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies[['original_title','popularity','vote_average']].head(10)
# Out:
#                                       original_title  popularity  vote_average
# 0                                            Minions         875           6.4
# 1                                       Interstellar         724           8.1
# 2                                           Deadpool         514           7.4
# 3                            Guardians of the Galaxy         481           7.9
# 4                                 Mad Max: Fury Road         434           7.2
# 5                                     Jurassic World         418           6.5
# 6  Pirates of the Caribbean: The Curse of the Bla...         271           7.5
# 7                     Dawn of the Planet of the Apes         243           7.3
# 8              The Hunger Games: Mockingjay - Part 1         206           6.6
# 9                                         Big Hero 6         203           7.8

# %% [markdown]
# ## List out Particular movie for Voting average and votecount

# %%
cur.execute('SELECT * FROM movies')
movies = cur.fetchall()
movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
movies[['original_title','vote_average','vote_count']]
# Out:
#                                 original_title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4768                               El Mariachi           6.6         238
# 4769                                 Newlyweds           5.9           5
# 4770                 Signed, Sealed, Delivered           7.0           6
# 4771                          Shanghai Calling           5.7           7
# 4772                         My Date with Drew           6.3          16
#
# [4773 rows x 3 columns]

# %% [markdown]
# # Director's Analysis

# %% [markdown]
# ## List out the director names with number of movies and revenue

# %%
cur.execute("SELECT name, COUNT(*) No_of_movies, SUM(revenue) FROM movies tb1 JOIN directors tb2 ON tb1.director_id = tb2.id GROUP BY name ORDER BY revenue DESC")
merge = cur.fetchall()
merge = pd.DataFrame(merge, columns = ['name','No_of_movies','revenue'])
merge
# Out:
#                  name  No_of_movies     revenue
# 0       James Cameron             7  5883569439
# 1     Colin Trevorrow             2  1517536602
# 2           James Wan             7  2362314787
# 3         Joss Whedon             3  2963831068
# 4          Chris Buck             1  1274219009
# ...               ...           ...         ...
# 2344       Adam Green             1           0
# 2345    Adam Goldberg             1           0
# 2346     Adam Carolla             1           0
# 2347  Aaron Schneider             1           0
# 2348       Aaron Hann             1           0
#
# [2349 rows x 3 columns]
